# %%
import requests

# %%
web = requests.get("https://www.iplt20.com/")
print(web)
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

# %%
web = requests.get("https://www.iplt20.com/")

# %%
web.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n    <title id="page_title" data-page-title="IPL T20 | Indian Premier League Official Website">IPL T20 | Indian Premier League Official Website</title>\n    <meta charset="UTF-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, user-scalable=no" />\n    <meta name="csrf-token" content="YLONKIvUSJUvVrJ4P30UGAAIjngaDQdex6SEh3XP">\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n    <link rel="canonical" href="https://www.iplt20.com">\n    <meta name="theme-color" content="#19398a">\n\n    <meta name="twitter:card" content="summary_large_image">\n    <meta name="og:type" content="website">\n    <meta name="twitter:title" content="IPL T20 | Indian Premier League Official Website">\n    <meta name="og:url"  content="https://www.iplt20.com">\n    <meta name="og:title"  content="IPL T20 | Indian Premier League Official Website">\n  \n    
# ...

# %%
soup = BeautifulSoup(web.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title data-page-title="IPL T20 | Indian Premier League Official Website" id="page_title">
#    IPL T20 | Indian Premier League Official Website
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, user-scalable=no" name="viewport">
#    <meta content="YLONKIvUSJUvVrJ4P30UGAAIjngaDQdex6SEh3XP" name="csrf-token"/>
#    <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#    <link href="https://www.iplt20.com" rel="canonical"/>
#    <meta content="#19398a" name="theme-color"/>
#    <meta content="summary_large_image" name="twitter:card"/>
#    <meta content="website" name="og:type"/>
#    <meta content="IPL T20 | Indian Premier League Official Website" name="twitter:title"/>
#    <meta content="https://www.iplt20.com" name="og:url"/>
# ...

# %%
soup.title
# Out:
# <title data-page-title="IPL T20 | Indian Premier League Official Website" id="page_title">IPL T20 | Indian Premier League Official Website</title>

# %%
soup.p
# Out:
# <p class="mb-0 w-100 text-center">Copyright © IPL 2024 All Rights Reserved.</p>

# %%
soup.a
# Out:
# <a href="https://www.bcci.tv/" target="_blank"><img alt="BCCI Logo" height="22" src="https://documents.iplt20.com//ipl/assets/images/BCCI_logo.png" width="23"/>BCCI.TV</a>

# %%
soup.h1
# Out:
# <h1 class="what-r-u-text-3 mb-0 mt-0 text-white wrut-drk ps-3">IPL Exclusive</h1>

# %% [markdown]
# kind of objects
# 1) Tag
# 2) Navigable string
# 3) Beautiful soup
# 4) comments

# %% [markdown]
# # Tag

# %%
tag = soup.html

# %%
type(tag)
# Out:
# bs4.element.Tag

# %%
tag = soup.p
tag
# Out:
# <p class="mb-0 w-100 text-center">Copyright © IPL 2024 All Rights Reserved.</p>

# %%
tag = soup.a 
tag
# Out:
# <a href="https://www.bcci.tv/" target="_blank"><img alt="BCCI Logo" height="22" src="https://documents.iplt20.com//ipl/assets/images/BCCI_logo.png" width="23"/>BCCI.TV</a>

# %% [markdown]
# # navigable string

# %%
tag = soup.p.string
tag
# Out:
# 'Copyright © IPL 2024 All Rights Reserved.'

# %% [markdown]
# # BeautifulSoup

# %%
soup.body
# Out:
# <body class="js-body-content" ng-app="MyApp">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PQ2QKF4" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="loader-main" style="display: none;">
# <div class="loader"></div>
# </div>
# <style>
#    .ap-copy {
#       padding-bottom: 90px;
#    }
# </style>
# <!-- widget start -->
# <!-- widget ends -->
# <section class="ap-banner-parent col-100 floatLft relative">
# <div class="ap-inner-banner-wrp col-100 floatLft relative">
# <div class="ap-slider-video" style="display: block;">
# <div class="ap-video-item ap-item-1 relative hoverVideoPlayNow" data-mainid="ap_inner_banner_wrp_video_58725455639915">
# <div class="w-100 pull-left ap-over-color">
# <div id="show_for_image_ap_inner_banner_wrp_video_58725455639915">
# ...

# %%
soup.find("p")
# Out:
# <p class="mb-0 w-100 text-center">Copyright © IPL 2024 All Rights Reserved.</p>

# %%
soup.findAll("p")
# Out:
# [<p class="mb-0 w-100 text-center">Copyright © IPL 2024 All Rights Reserved.</p>,
#  <p class="cookie__message">We and selected third parties use cookies or similar technologies for technical purposes and, with your consent, for other purposes as specified in the <a href="https://www.iplt20.com/cookie-policy" target="_blank">cookie policy.</a></p>,
#  <p class="d-flex align-items-center">
#  <span class="d-flex align-items-center me-2 popupdate"></span>|<img alt="" class="mx-2" src="https://documents.iplt20.com//ipl/assets/images/new-eye.svg"/><span class="popupview me-2">0</span>|
#                                                      <span class="d-flex align-items-center mx-2 videopageduration">
#  </span>
#  </p>]

# %%
web.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n    <title id="page_title" data-page-title="IPL T20 | Indian Premier League Official Website">IPL T20 | Indian Premier League Official Website</title>\n    <meta charset="UTF-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, user-scalable=no" />\n    <meta name="csrf-token" content="YLONKIvUSJUvVrJ4P30UGAAIjngaDQdex6SEh3XP">\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n    <link rel="canonical" href="https://www.iplt20.com">\n    <meta name="theme-color" content="#19398a">\n\n    <meta name="twitter:card" content="summary_large_image">\n    <meta name="og:type" content="website">\n    <meta name="twitter:title" content="IPL T20 | Indian Premier League Official Website">\n    <meta name="og:url"  content="https://www.iplt20.com">\n    <meta name="og:title"  content="IPL T20 | Indian Premier League Official Website">\n  \n    
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title data-page-title="IPL T20 | Indian Premier League Official Website" id="page_title">
#    IPL T20 | Indian Premier League Official Website
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, user-scalable=no" name="viewport">
#    <meta content="YLONKIvUSJUvVrJ4P30UGAAIjngaDQdex6SEh3XP" name="csrf-token"/>
#    <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#    <link href="https://www.iplt20.com" rel="canonical"/>
#    <meta content="#19398a" name="theme-color"/>
#    <meta content="summary_large_image" name="twitter:card"/>
#    <meta content="website" name="og:type"/>
#    <meta content="IPL T20 | Indian Premier League Official Website" name="twitter:title"/>
#    <meta content="https://www.iplt20.com" name="og:url"/>
# ...

# %%
soup.find_all('p')
# Out:
# [<p class="mb-0 w-100 text-center">Copyright © IPL 2024 All Rights Reserved.</p>,
#  <p class="cookie__message">We and selected third parties use cookies or similar technologies for technical purposes and, with your consent, for other purposes as specified in the <a href="https://www.iplt20.com/cookie-policy" target="_blank">cookie policy.</a></p>,
#  <p class="d-flex align-items-center">
#  <span class="d-flex align-items-center me-2 popupdate"></span>|<img alt="" class="mx-2" src="https://documents.iplt20.com//ipl/assets/images/new-eye.svg"/><span class="popupview me-2">0</span>|
#                                                      <span class="d-flex align-items-center mx-2 videopageduration">
#  </span>
#  </p>]

# %%
class_data = soup.find("div", class_ = "ap-inner-banner-wrp col-100 floatLft relative")
print(class_data)
# Out:
# <div class="ap-inner-banner-wrp col-100 floatLft relative">
# <div class="ap-slider-video" style="display: block;">
# <div class="ap-video-item ap-item-1 relative hoverVideoPlayNow" data-mainid="ap_inner_banner_wrp_video_58725455639915">
# <div class="w-100 pull-left ap-over-color">
# <div id="show_for_image_ap_inner_banner_wrp_video_58725455639915">
# <img alt="img" aria-label="banner" class="mobile-height" height="720" src="https://brightcove.iplt20.com/output/input/6365129698112-1732723250.jpg" width="1280"/>
# <span></span>
# </div>
# <div class="h_banner_vid_div" data-id="ap_inner_banner_wrp_video_58725455639915" id="show_for_video_ap_inner_banner_wrp_video_58725455639915" style="display: none">
# <!--start player -->
# <!-- <div>
#                               <video-js id="myAutoPlayVid_ap_inner_banner_wrp_video_58725455639915" data-account="3588749423001" data-video-id="" data-player="default"
# ...

# %%
class_data.find_all("p")
# Out:
# []
